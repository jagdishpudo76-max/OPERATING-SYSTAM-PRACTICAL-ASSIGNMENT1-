# %%
import platform
import socket
import os

print("----- System Information -----")

# Operating System details
print("OS Name:", platform.system())
print("OS Version:", platform.version())
print("OS Release:", platform.release())

# Machine details
print("Machine Type:", platform.machine())
print("Processor:", platform.processor())

# Computer name and IP address
print("Computer Name:", socket.gethostname())
print("IP Address:", socket.gethostbyname(socket.gethostname()))

# Python details
print("Python Version:", platform.python_version())

# Current working directory
print("Current Directory:", os.getcwd())
# Out:
# ----- System Information -----
# OS Name: Windows
# OS Version: 10.0.26200
# OS Release: 11
# Machine Type: AMD64
# Processor: AMD64 Family 25 Model 124 Stepping 0, AuthenticAMD
# Computer Name: LAPTOP-G8MTL1CS
# IP Address: 192.168.20.124
# Python Version: 3.14.0
# Current Directory: c:\Users\JAGDEESH PUDO\Desktop\MCA for OS\JAGDISH PUDO\OPRETING SYSTAM\block\practical assgnment.pymb
