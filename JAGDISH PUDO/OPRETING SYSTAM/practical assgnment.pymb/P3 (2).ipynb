# %%
#write a python program to display total memory, used memory, and available memory using psutil library

import psutil
memory = psutil.virtual_memory()
print(f"Total memory: {memory.total/(1024**2): .2f}MB")
print(f"used memory: {memory.used/(1024**2): .2f}MB")
print(f" Available Memory: {memory.available/(1024**2): .2f}MB")
# Out:
# Total memory:  15638.86MB
# used memory:  9232.03MB
#  Available Memory:  6406.84MB
