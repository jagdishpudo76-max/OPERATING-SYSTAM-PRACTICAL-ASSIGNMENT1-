# %%
import time

print("Container started")
for i in range(5):
    print(f"Processing task {i+1}")
    time.sleep(1)
print("Container finished")
# Out:
# Container started
# Processing task 1
# Processing task 2
# Processing task 3
# Processing task 4
# Processing task 5
# Container finished
